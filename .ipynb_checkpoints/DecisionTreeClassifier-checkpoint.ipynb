# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import tree
import numpy as np

# %%
df = pd.read_csv('final_features.csv')
df.drop(["Unnamed: 0"], inplace=True, axis=1)
df = df.dropna()
X = df.drop(["date", "start_station_name", "city", "weekday"], axis=1)
y = df[["total_bike_trips"]]

# %%
def decision_tree(X, y, test_size=0.33, max_depth=None):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
    classifier = DecisionTreeClassifier(max_depth=max_depth)
    classifier.fit(X_train, y_train)
    print("Score: " + str(classifier.score(X_test, y_test)))
    print("Maximum depth: " + str(classifier.get_depth()))
    print("Number of leaves: " + str(classifier.get_n_leaves()))
    return (classifier, X_train, X_test, y_train, y_test)

def print_misclassified(classifier, X_test, y_test):
    pred = classifier.predict(X_test)
    for x in zip(pred, y_test["total_bike_trips"]):
        if x[0] != x[1]:
            print("Predicted " + str(x[0]) + " but correct value was " + str(x[1]))

# %%
classifier, X_train, X_test, y_train, y_test = decision_tree(X,y)
print_misclassified(classifier, X_test, y_test)
# Out:
# Score: 0.9997486489883122
# Maximum depth: 39
# Number of leaves: 45
# Predicted 45 but correct value was 43
# Predicted 45 but correct value was 52
# Predicted 45 but correct value was 43
# Predicted 43 but correct value was 44

# %%
classifier, X_train, X_test, y_train, y_test = decision_tree(X,y,max_depth=10)
print_misclassified(classifier, X_test, y_test)
# Out:
# Score: 0.9645595073520171
# Maximum depth: 10
# Number of leaves: 11
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 30
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 20
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 30
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 37
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 27
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 23
# Predicted 11 but correct value was 28
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 33
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 27
# Predicted 11 but correct value was 27
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 38
# Predicted 11 but correct value was 20
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 30
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 20
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 25
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 20
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 34
# Predicted 11 but correct value was 25
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 20
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 33
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 30
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 27
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 34
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 25
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 27
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 32
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 28
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 27
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 23
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 31
# Predicted 11 but correct value was 29
# Predicted 11 but correct value was 26
# Predicted 11 but correct value was 26
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 27
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 26
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 38
# Predicted 11 but correct value was 28
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 27
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 20
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 36
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 34
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 28
# Predicted 11 but correct value was 25
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 23
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 23
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 26
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 35
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 32
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 25
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 37
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 35
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 29
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 27
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 30
# Predicted 11 but correct value was 23
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 38
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 20
# Predicted 11 but correct value was 27
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 29
# Predicted 11 but correct value was 23
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 34
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 25
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 35
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 30
# Predicted 11 but correct value was 28
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 34
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 20
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 20
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 35
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 23
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 30
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 35
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 25
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 31
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 37
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 25
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 20
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 27
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 31
# Predicted 11 but correct value was 23
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 41
# Predicted 11 but correct value was 32
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 25
# Predicted 11 but correct value was 28
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 20
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 29
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 20
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 26
# Predicted 11 but correct value was 23
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 25
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 31
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 42
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 25
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 25
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 31
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 27
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 20
# Predicted 11 but correct value was 41
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 31
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 23
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 30
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 20
# Predicted 11 but correct value was 26
# Predicted 11 but correct value was 20
# Predicted 11 but correct value was 29
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 26
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 27
# Predicted 11 but correct value was 20
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 26
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 23
# Predicted 11 but correct value was 32
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 29
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 52
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 29
# Predicted 11 but correct value was 28
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 27
# Predicted 11 but correct value was 28
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 33
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 26
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 20
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 28
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 25
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 19
# Predicted 11 but correct value was 28
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 31
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 34
# Predicted 11 but correct value was 28
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 27
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 20
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 16
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 41
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 13
# Predicted 11 but correct value was 35
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 23
# Predicted 11 but correct value was 42
# Predicted 11 but correct value was 25
# Predicted 11 but correct value was 25
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 42
# Predicted 11 but correct value was 35
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 21
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 17
# Predicted 11 but correct value was 12
# Predicted 11 but correct value was 24
# Predicted 11 but correct value was 18
# Predicted 11 but correct value was 20
# Predicted 11 but correct value was 15
# Predicted 11 but correct value was 35
# Predicted 11 but correct value was 14
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 22
# Predicted 11 but correct value was 12
